# %%
import numpy as np

# %%
for i in np.arange(0.0,2.0*np.pi,0.01):
    print('cos(%f)= %.25e'%(i,np.cos(i)))# el comando %.(numero de cifras significativas)e
# Out:
# cos(0.000000)= 1.0000000000000000000000000e+00
# cos(0.010000)= 9.9995000041666526335859544e-01
# cos(0.020000)= 9.9980000666657775632018001e-01
# cos(0.030000)= 9.9955003374898754309185733e-01
# cos(0.040000)= 9.9920010666097791585116283e-01
# cos(0.050000)= 9.9875026039496628271763257e-01
# cos(0.060000)= 9.9820053993520418966767238e-01
# cos(0.070000)= 9.9755100025327958501719650e-01
# cos(0.080000)= 9.9680170630261943909289357e-01
# cos(0.090000)= 9.9595273301199427340435477e-01
# cos(0.100000)= 9.9500416527802582056239089e-01
# cos(0.110000)= 9.9395609795669681574281640e-01
# cos(0.120000)= 9.9280863585386625036477426e-01
# cos(0.130000)= 9.9156189371478808958215723e-01
# cos(0.140000)= 9.9021599621263711732410684e-01
# cos(0.150000)= 9.8877107793604224195149754e-01
# cos(0.160000)= 9.8722728337562692946249854e-01
# cos(0.170000)= 9.8558476690956076105010197e-01
# cos(0.180000)= 9.8384369278812144887780278e-01
# cos(0.190000)= 9.8200423511727030767559654e-01
# ...
